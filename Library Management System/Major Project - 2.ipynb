# %% [markdown]
# # Make a Library Management System which has the following functionalities:
#
# ## Database of Books that Contains | Dictionary
#
# ● Book Name
#
# ● Book ID
#
# ● Quantity
#
# ● Genre
#
# ● Price
#
# ● Author
#
# ## Database of Students
# ● Student Name
#
# ● Student ID
#
# ● Graduation Year
#
# ● Graduation Degree
#
# ● Books Issued | List of Books ID with Issue and Expiry Date

# %% [markdown]
# **Dictionary structure of books.json**
#
# ```python
#
# books = {
#     'book_id_1': {
#         'name'     : # string   value
#         'quantity' : # integer  value
#         'genre'    : # string   value
#         'price'    : # floating value
#         'author'   : # string   value
#     },
#     'book_id_2': { ... },
#     ...
# }
# ```
#
# **Dictionary structure of students.json**
#
# ```python
#
# students = {
#     'student_id_1': {
#         'name'            : # string   value
#         'graduation year' : # integer  value
#         'degree'          : # string   value
#         'taken'           : # integer values --> 0, 1, 2
#         'issued'          : [ ('book_ids','expire_date'), ... ] # list of book ids may varies
#     },
#     'student_id_2': { ... },
#     ...
# }
# ```

# %% [markdown]
# ## Import Libraries

# %%
import json as js
import pandas as pd
from IPython.display import clear_output
from datetime import datetime  as dt
from datetime import timedelta as td

# %% [markdown]
# ## Read and Write Json Files function

# %%
# reads json file and return dictionary 
def read_file( name = 'book' ):
    
    # writing extension of file as .json
    name += 's.json'
    
    # Opening json file in read mode
    fr    = open( name ,'r')

    # Loading json file into dictionary
    r     = js.loads( fr.read() )

    # Closing the file
    fr.close()
    
    # Return dictionary
    return r

# %%
# write dictionary data into json file 
def write_file(var, name = 'book' ):
    
    # writing extension of file as .json
    name += 's.json'
    
    # Opening json file in write mode
    fw    = open( name ,'w')

    # Dumping dictionary into json file  
    fw.write(js.dumps(var))

    # Closing the file
    fw.close()

# %% [markdown]
# ## Choice function

# %%
# Program for choice return choice or False for invalid input 
def choices(limit):
    
    # Taking input of choice from user
    choice = input('Enter your choice number: ')
    
    # try block to catch error for int function
    try:
        
        # convert str to int if error then go to except block
        choice = int(choice)
        
        # valid choice and return choice as o/p
        if 0 < choice <= limit:
            return choice
        
        # invalid choice and return False as o/p
        else :
            print('Enter valid number try again ....')
            print('-'*40)
            return False
        
    # except block for int errors and return False as o/p
    except:
        print('Invalid input try again ....')
        print('-'*40)
        return False

# Getting input of book_id and scan_id   
def inputs():
    
    # While Loop until inputs are valid
    while True:
        
        #
        try:
            book_id    = input('Scan / Type Book id: ').upper()

            if not book_id in books    :

                print('Book id not found')
                continue


            stud_id    = input('Scan / Type student id: ').upper()

            if not stud_id in students :

                print('Student id not found')
                continue

            break
        except:
            print('Try Again ... ')
            
    return (book_id,stud_id)

# %% [markdown]
# # Book Issue and Reissue Application

# %%
def book_avail():
    # Loop this message until exit
    while True:
        # printing statement
        print('Check Availiability')
        print('1. Search by Name')
        print('2. Search by Author')
        print('3. Search by Genres')
        print('4. Exit')
        
        # getting choices
        choice = choices(4)
        print('*'* 80)
        
        # if choice is invalid
        if not choice: continue
        
        #if choice is exit 
        elif choice == 4: break
            
        else:
            # search by choice
            search(choice)

def search(choice):
    
    # Print input message as per choice
    tag     = 'Name' if choice == 1 else ( 'Author' if choice == 2 else 'Genres' )
    msg     = f'Enter the {tag}: '
    
    # getting word to be searched
    search  = input(msg)
    
    # Fetching book dataset
    books    = read_file()
    
    # list of searched elements will store in list
    searched = []
    max_len  = 0
    
    # looping for all dictionary values 
    for book in books.values():
        
        # getting data as per choice
        tags = book[tag.lower()]

        # if word found in tags
        if search.lower() in tags.lower():
            
            # retrive name of book 
            name     = book['name']
            
            # checking status of availiablity
            status   = '   AVAIL' if book['quantity'] > 0 else 'NOTAVAIL'
            
            # adding in list of searched element 
            searched.append( (name,status) )
            
            # for print purpose
            max_len  = len(name) if len(name) > max_len else max_len
    
    # list of searched element is empty
    if searched == []:
        print('Book not found')
        print('*'*80)
    
    # list of searched element is not empty
    else:
        
        # print tags for genres/author and its value
        if choice != 1:
            tag = tag.upper()
            print(tag,':',search)
        
        # print list of searched element 
        print('-'*(max_len+14))
        print('NAMES'.ljust(max_len),'  STATUS')
        print('-'*(max_len+14))
        
        for name,status in searched:
            
            print(name.ljust(max_len),status)
        
        print('*'*(max_len+14))

# %%
def check_status(issued,flag = True):
    
    # intialised status as per flag 
    # if flag True return status in bool
    # if flag False return data of book_ids and expire_dates in tuple 
    
    status = True if flag else ()
    
    # loop for every issued book
    for book , date in issued:
      
        # Difference of expire from today
        delta = dt.now() - dt.strptime(date,'%d-%m-%y')
        
        # if difference of days is +ve --> penalty
        if delta.days > 0:
            
            # for check status
            if flag:
                # print penalty message, set status False & Break the loop
                print(book ,'is expired at ', date, 'pay fine')
                status = False
                break
            
            # return list of books_ids and expire_date 
            else:
                # if first entry
                if status == ():
                    status        = (book, date,1)
                    
                # if not first entry
                else:
                    books , dates, count = status
                    books        += ', ' + book
                    dates        += ', ' + date
                    status        = (books, dates , count +1)
                
            
    
    # return status
    return status
    


def book_issue(book_id,stud_id,books,students):
    
    # getting list of issued of that stud_id
    issued     = students[stud_id ]['issued']
    
    # checking status of penalty
    if check_status(issued):
        
        # genrating expire date for that book
        expire = dt.now() + td( days = 28)
        expire = expire.strftime('%d-%m-%y')

        # initizise flag as True
        flag   = True
        
        # loop for all issued ---> Reissued operation 
        for idx in range(len(issued)):
            
            # book_id found in list then reissued , set flag False & break loop
            
            if issued[idx][0] == book_id:
                flag           = False
                issued[idx][1] = expire
                break
        
        # Flag still true    ---> new book issue operation
        if flag: 
            
            # Added book_id, expire in issued 
            issued.append( (book_id,expire) )
            
            # Updating book quantity of that book_id and saving in database
            
            books[ book_id  ]['quantity'] -=  1
            write_file( books )
        
        # Updating student issued of that stud_id and saving in database
        students[stud_id ]['issued']  = issued
        write_file( students, 'student')
        
        # print sucessfully operation message
        print('Book issued sucessfully')

# %%
def book_return(book_id,stud_id,books,students):
    
    # Updating student issued of that stud_id and saving in database
    books[book_id]['quantity'] += 1
    write_file(books)
    
    # getting list of issued of that stud_id
    issued    = students[stud_id]['issued']
    
    # loop for all issued        --> Checking Penalty 
    for idx in range(len(issued)):
        
        # finding  book_id in issued list if found at end break loop
        if issued[idx][0] == book_id:
            
            # difference of expire date from today
            delta = dt.now() - dt.strptime(issued[idx][1],'%d-%m-%y')
            
            # difference is +ve Warning message of penalty to student
            if delta.days > 0:
                print('WARNING :Late submission on this',book_id,'pay fine')
            
            # difference is -ve remove book , expire from issued list 
            else:
                issued.remove(issued[idx])
                
                # update issued list of that stud_id and saving in database
                students[stud_id]['issued']  =  issued
                write_file(students,'student')
                print('Book return sucessfully')
            break

# %%
def blacklist():
    
    students  = read_file('student')
    
    blacklist = { key : [] for key in [ 'id', 'name', 'graduation_year', 'degree', 'books', 'expired' ] }
    
    for stud_id , student in students.items():
        
        book_expired = check_status(student['issued'],False)
        
        if book_expired != ():
            
            blacklist['id'             ].append(stud_id          )
            
            blacklist['name'           ].append(student['name'           ])
            blacklist['graduation_year'].append(student['graduation year'])
            blacklist['degree'         ].append(student['degree'         ])
            
            blacklist['books'          ].append(book_expired[0           ])
            blacklist['expired'        ].append(book_expired[1           ])
    
    file_name = 'Blacklist Student till ' + dt.now().strftime('%d-%m-%y') + '.csv'
    pd.DataFrame(blacklist).to_csv(file_name,index = False)

# %%
def pay_fine():
    
    stud_id = None
    
    students      = read_file('student')
     # While Loop until inputs are valid
    while True:
        
        #
        try:
            stud_id = input('Scan / Type student id: ').upper()

            if not stud_id in students :

                print('Student id not found')
                continue

            break
        except:
            print('Try Again ... ') 
            
    issued       = students[stud_id]['issued']
    book_expired = check_status(issued,flag = False)
    
    if book_expired != ():
        
        print('You have to pay fine for', book_expired[2], 'books')
        print('Total Fine', 500 * book_expired[2])
        
        paid = input("Do you want to pay Type 'paid' for done payment ").lower()
        
        if paid == 'paid':
            
            for book_id , expired in issued:
                
                print(book_id,expired)
                
                if book_id in  book_expired[0]:
                    
                    issued.remove([book_id , expired])
            
            students[stud_id]['issued'] = issued
            
            write_file(students,'student')
            
            print('Payment done and Penalty removed')
            
    else:
        print('Cleared')

# %%
if __name__ == '__main__':
    
    while True:
        
        print('Welcome to Library Management')
        print('1. Book Avail')
        print('2. Book Issue / Reissue')
        print('3. Book return ')
        print('4. List of Blacklist Student')
        print('5. Pay fine')
        print('6. Exit')
        
        choice = choices(6)
        
        if not choice   : continue
        
        elif choice == 6: break
        
        elif choice == 1: book_avail()
            
        elif choice < 4 :
            
            books            = read_file (         )
            students         = read_file ('student')
            
            
            book_id ,stud_id = inputs()
            
            
            if   choice == 2 : book_issue (book_id ,stud_id, books, students)
                
            else             : book_return(book_id ,stud_id, books, students)
            
        elif choice == 4 : blacklist()
        else             : pay_fine()
            
        print('*'*80)
# Out:
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 1
# Check Availiability
# 1. Search by Name
# 2. Search by Author
# 3. Search by Genres
# 4. Exit
# Enter your choice number: 1
# ********************************************************************************
# Enter the Name: harry
# -------------------------------------------------------------------------------------------------------------------------------------------
# NAMES                                                                                                                           STATUS
# -------------------------------------------------------------------------------------------------------------------------------------------
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Samsara: Enter the Valley of the Gods ("India's answer to Harry Potter")                                                         AVAIL
# Harry Potter and the Goblet of Fire                                                                                              AVAIL
# Harry Potter and the Chamber of Secrets                                                                                          AVAIL
# Harry Potter and the Prisoner of Azkaban                                                                                         AVAIL
# Harry Potter and the Order of the Phoenix                                                                                        AVAIL
# Harry Potter and the Half-Blood Prince                                                                                           AVAIL
# Harry Potter and the Deathly Hallows                                                                                             AVAIL
# Harry Potter and the Cursed Child - Parts One and Two: The Official Playscript of the Original West End Production               AVAIL
# Harry Potter and the Chamber of Secrets: Illustrated Edition                                                                     AVAIL
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Harry Potter Box Set: The Complete Collection (Set of 7 Volumes)                                                                 AVAIL
# Samsara: Enter the Valley of the Gods ("India's answer to Harry Potter")                                                         AVAIL
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Samsara: Enter the Valley of the Gods ("India's answer to Harry Potter")                                                         AVAIL
# Harry Potter Box Set: The Complete Collection (Set of 7 Volumes)                                                                 AVAIL
# Harry Potter 1-3 Box Set: A Magical Adventure Begins                                                                             AVAIL
# Harry Potter and the Goblet of Fire                                                                                              AVAIL
# Harry Potter and the Chamber of Secrets                                                                                          AVAIL
# Harry Potter and the Order of the Phoenix                                                                                        AVAIL
# Harry Potter and the Prisoner of Azkaban                                                                                         AVAIL
# Harry Potter and the Chamber of Secrets (Harry Potter 2)                                                                         AVAIL
# Harry Potter and the Prisoner of Azkaban                                                                                         AVAIL
# Harry Potter and the Order of the Phoenix                                                                                        AVAIL
# Harry Potter and the Half-Blood Prince                                                                                           AVAIL
# Harry Potter and the Goblet of Fire                                                                                              AVAIL
# Harry Potter and the Deathly Hallows                                                                                             AVAIL
# Harry Potter and the Half Blood Prince                                                                                           AVAIL
# Harry Potter and the Cursed Child - Parts One and Two: The Official Playscript of the Original West End Production               AVAIL
# Harry Potter and the Philosopher's Stone, Book 1                                                                                 AVAIL
# Harry Potter and the Chamber of Secrets (Harry Potter 2) + Harry Potter and the Prisoner of Azkaban (Harry Potter 3) (Set of     AVAIL
# Harry Potter and the Order of the Phoenix, Book 5                                                                                AVAIL
# Harry Potter and the Philosopher's Stone + Harry Potter and the Chamber of Secrets (Harry Potter 2) (Set of 2 Books)             AVAIL
# Harry Potter and the Prisoner of Azkaban, Book 3                                                                                 AVAIL
# Harry Potter and the Cursed Child - Parts One and Two: The Official Playscript of the Original West End Production               AVAIL
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Harry Potter and the Philosopher's Stone                                                                                         AVAIL
# Samsara: Enter the Valley of the Gods ("India's answer to Harry Potter")                                                         AVAIL
# Harry Potter Box Set: The Complete Collection (Set of 7 Volumes)                                                                 AVAIL
# Harry Potter - A History of Magic: The eBook of the Exhibition                                                                   AVAIL
# *******************************************************************************************************************************************
# Check Availiability
# 1. Search by Name
# 2. Search by Author
# 3. Search by Genres
# 4. Exit
# Enter your choice number: 2
# ********************************************************************************
# Enter the Author: Rowling
# AUTHOR : Rowling
# --------------------------------------------------------------------------------------------------------------------------------
# NAMES                                                                                                                STATUS
# --------------------------------------------------------------------------------------------------------------------------------
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter and the Goblet of Fire                                                                                   AVAIL
# Harry Potter and the Chamber of Secrets                                                                               AVAIL
# Harry Potter and the Prisoner of Azkaban                                                                              AVAIL
# Harry Potter and the Order of the Phoenix                                                                             AVAIL
# Harry Potter and the Half-Blood Prince                                                                                AVAIL
# Harry Potter and the Deathly Hallows                                                                                  AVAIL
# Harry Potter and the Cursed Child - Parts One and Two: The Official Playscript of the Original West End Production    AVAIL
# Harry Potter and the Chamber of Secrets: Illustrated Edition                                                          AVAIL
# Fantastic Beasts: The Crimes of Grindelwald - The Original Screenplay                                                 AVAIL
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter Box Set: The Complete Collection (Set of 7 Volumes)                                                      AVAIL
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter Box Set: The Complete Collection (Set of 7 Volumes)                                                      AVAIL
# Harry Potter 1-3 Box Set: A Magical Adventure Begins                                                                  AVAIL
# Harry Potter and the Goblet of Fire                                                                                   AVAIL
# Harry Potter and the Chamber of Secrets                                                                               AVAIL
# Harry Potter and the Order of the Phoenix                                                                             AVAIL
# Harry Potter and the Prisoner of Azkaban                                                                              AVAIL
# Harry Potter and the Chamber of Secrets (Harry Potter 2)                                                              AVAIL
# Harry Potter and the Prisoner of Azkaban                                                                              AVAIL
# Harry Potter and the Order of the Phoenix                                                                             AVAIL
# Harry Potter and the Half-Blood Prince                                                                                AVAIL
# Harry Potter and the Goblet of Fire                                                                                   AVAIL
# Harry Potter and the Deathly Hallows                                                                                  AVAIL
# Harry Potter and the Half Blood Prince                                                                                AVAIL
# Harry Potter and the Cursed Child - Parts One and Two: The Official Playscript of the Original West End Production    AVAIL
# Harry Potter and the Philosopher's Stone, Book 1                                                                      AVAIL
# Harry Potter and the Order of the Phoenix, Book 5                                                                     AVAIL
# Harry Potter and the Prisoner of Azkaban, Book 3                                                                      AVAIL
# Harry Potter and the Cursed Child - Parts One and Two: The Official Playscript of the Original West End Production    AVAIL
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter and the Philosopher's Stone                                                                              AVAIL
# Harry Potter Box Set: The Complete Collection (Set of 7 Volumes)                                                      AVAIL
# ********************************************************************************************************************************
# Check Availiability
# 1. Search by Name
# 2. Search by Author
# 3. Search by Genres
# 4. Exit
# Enter your choice number: 3
# ********************************************************************************
# Enter the Genres: Exam
# GENRES : Exam
# -------------------------------------------------------------------------------------------------------------------------------------------
# NAMES                                                                                                                           STATUS
# -------------------------------------------------------------------------------------------------------------------------------------------
# KVS PEDAGOGY MASTER BOOK (BILINGUAL) THEORY with PRACTICE MCQ's                                                                  AVAIL
# Indian Polity ( English| 6th Revised Edition) | UPSC | Civil Services Exam | State Administrative Exams                          AVAIL
# BlackBook of General Awareness January 2023 by Nikhil Gupta                                                                      AVAIL
# Examcart KVS PRT Pedagogy English Medium Textbook - Perspective on Education & Leadership for 2023 Exam (Prateek Shivalik)       AVAIL
# Examcart KVS PRT Textbook Maths & EVS Environmental Science for 2023 Exam (Prateek Shivalik | English Medium)                    AVAIL
# UGC NET /SET/JRF Paper 1 Teaching and Research Aptitude - 2019- 2021 fully solved papers including Oct- Dec 2021 | Includes N    AVAIL
# 28 Years UPSC Civil Services IAS Prelims Topic-wise Solved Papers 1 & 2 (1995 - 2022) 13th Edition                               AVAIL
# BlackBook of English Vocabulary January 2022                                                                                     AVAIL
# Examcart KVS PRT Pedagogy Hindi Medium Textbook - Perspective on Education & Leadership for 2023 Exam (Prateek Shivalik)         AVAIL
# Examcart KVS PRT Complete Study Guidebook in Hindi Medium For 2023 Exams (Prateek Shivalik)                                      AVAIL
# Examcart KVS Study Guide Book For 2023 Exams in English                                                                          AVAIL
# Examcart KVS PRT Paryaavaran Vigyaan aur Ganit (Environmental Science & Mathematics) Study Book for 2023 Exams in Hindi          AVAIL
# Oxford Student Atlas for India, Fourth Edition - Useful for Competitive Exams                                                    AVAIL
# MTG Objective NCERT at your FINGERTIPS - Biology, Best NEET Books (Based on NCERT Pattern - Latest & Revised Edition 2022)       AVAIL
# Word Power Made Easy | Over a million copies sold Worldwide | With Self Assessment Activities | Ideal For IELTS & TOEFL Prepa    AVAIL
# SSC Maths 6800 TCS MCQ Chapter wise 3rd Edition English medium                                                                   AVAIL
# Quantitative Aptitude for Competitive Examinations: (Fully Revised Video Edition) 2022                                           AVAIL
# SSC English TCS 7600+ MCQ Topic wise Book with the detailed explanation I 3rd edition                                            AVAIL
# General Knowledge 2023                                                                                                           AVAIL
# Indian Economy (English| 14th Edition) | UPSC | Civil Services Exam | State Administrative Exams                                 AVAIL
# General Knowledge                                                                                                                AVAIL
# Complete Maths Brahamastra formula book for all Competetive Exams                                                                AVAIL
# Disha 120 JEE Main Online (2022 - 2012) & Offline (2018 - 2002) Physics, Chemistry & Mathematics Chapter-wise + Topic-wise Pr    AVAIL
# SSC Reasoning 7200 TCS MCQ Chapter wise English medium 3rd edition                                                               AVAIL
# AIBE Bare Acts Combo without Notes 2023 EDITION- as per Bar Council of India Guidelines set of 18 Bare Acts covering 32 Acts     AVAIL
# HOW I TOPPED THE UPSC AND HOW YOU CAN TOO : What It Really Takes to Crack the World’s Toughest Exam                              AVAIL
# MTG 35 Years NEET Previous Year Solved Question Papers with NEET Chapterwise Topicwise Solutions - NEET 2023 Preparation Book    AVAIL
# KVS MASTER PRT TGT PGT | Bilingual Book | Rohit Vaidwan | Adhyayan Mantra                                                        AVAIL
# The Answer Writing Manual for UPSC Civil Services & State PSC Examinations                                                       AVAIL
# SSC Maths Chapter - Wise 8000+ TCS - MCQ (Bilingual) by Gagan Pratap Sir Champion Publication                                    AVAIL
# A Modern Approach To Verbal & Non-Verbal Reasoning (Video Edition)  (2022-23)                                                    AVAIL
# Objective General English                                                                                                        AVAIL
# Certificate Physical And Human Geography (English) | Best Suited for UPSC aspirants and Other Competitive Examinations           AVAIL
# PMF IAS Environment for UPSC 2022-23                                                                                             AVAIL
# How to Prepare for QUANTITATIVE APTITUDE for CAT |10th Edition | With CAT Practice Tests on Pull Marks                           AVAIL
# The Yearly Current Affairs 2023 for Competitive Exams - 8th Edition | Latest Events, Issues, Ideas & People | UPSC, State PSC    AVAIL
# NTA UGC NET/SET/JRF : Hindi Paper 1, Teaching and Research Aptitude - 2019- 2021 fully solved papers including Oct- Dec 2021     AVAIL
# Environment - 9/edition, 2022-23                                                                                                 AVAIL
# Word Power Made Easy By Norman Lewis (More than 700 Pages)                                                                       AVAIL
# India & World Map ( Both Political & Physical ) with Constitution of India Chart, History of India Chart & Geography Terms Ch    AVAIL
# Educart Latest ABHYAAS Unit-wise NEET Mock Test Papers (15 Mock Papers) (Minor/Major) on NEET 2023 Paper Pattern (with explan    AVAIL
# The Official Cambridge Guide To Ielts Student's Book With Answers With Dvd Rom                                                   AVAIL
# Errorless 45 Previous Years IIT JEE Advanced (1978 - 2022) + JEE Main (2013 - 2022) Physics, Chemistry & Mathematics Chapterw    AVAIL
# Objective NCERT at your Fingertips for NEET-AIIMS - Chemistry                                                                    AVAIL
# NTA UGC NET/ JRF/ SET 2023 Complete Concepts General Paper 1 - Updated New 5th Edition 2023 - Way to JRF (Paperback, Navdeep     AVAIL
# Indian Art and Culture ( English| 4th Edition) | UPSC | Civil Services Exam | State Administrative Exams                         AVAIL
# English by Neetu SIngh Vol - 1 (English Medium) | Kd Publication | New 2022                                                      AVAIL
# SSC General Studies 6500 Chapter wise English medium 3rd edition                                                                 AVAIL
# DAMS DVT Workbook-Ultimate NEETPG Revision Course                                                                                AVAIL
# Disha 120 JEE Main Chemistry Online (2022 - 2012) & Offline (2018 - 2002) Chapter-wise + Topic-wise Previous Years Solved Pap    AVAIL
# Pathfinder NDA/NA National Defence Academy & Naval Academy Entrance Examination                                                  AVAIL
# SSC CHSL (10+2) Combined Higher Secondary Tier 1 Guide 2022                                                                      AVAIL
# Lucent's General Knowledge And Arihant General Knowledge 2022 - Set Of 2 Books                                                   AVAIL
# Objective Computer Awareness                                                                                                     AVAIL
# NTA UGC NET / JRF / SET General Paper 1 Teaching & Research Aptitude                                                             AVAIL
# A BRIEF HISTORY OF MODERN INDIA                                                                                                  AVAIL
# Physics Wallah Objective NCERT Punch Physics Chemistry, and Biology for Competitive Exams (NEET and CUET) | Includes A&R and     AVAIL
# Handbook of Physics                                                                                                              AVAIL
# MTG Objective NCERT at your FINGERTIPS - Physics, Best Books for NEET & JEE Preparation (Based on NCERT Pattern - Latest & Re    AVAIL
# Quantitative Aptitude for Competitive Examinations                                                                               AVAIL
# BlackBook of Samanya Jagrukta (General Awareness) - Hindi March 2022 by Nikhil Gupta                                             AVAIL
# General Knowledge 2023                                                                                                           AVAIL
# Cracking The CSAT (Civil Services Aptitude Test) Paper-2                                                                         AVAIL
# Indian Economy (English| 3rd Edition) | UPSC | Civil Services Exam | State Administrative Exams                                  AVAIL
# Modern Indian History UPSC Civil Services Exam | Modern Indian History Book (English 1st Edition) for State PCS Exams By Stud    AVAIL
# SSC CGL Tier 2 Computer Knowledge Book English Medium                                                                            AVAIL
# Disha Objective NCERT Xtract Biology for NTA NEET 8th Edition | One Liner Theory, MCQs on every line of NCERT, Tips on your F    AVAIL
# भारत की राजव्यवस्था ( Bharat Ki Rajvyavastha) |6th Revised Edition |UPSC | Civil Services Exam | State Administrative Exams      AVAIL
# 10 Previous Year Topic Wise UPSC Civil Services IAS Mains Solved Papers (2022 to 2013) for Paper B (Compulsory English), Pape    AVAIL
# Disha 120 JEE Main Mathematics Online (2022 - 2012) & Offline (2018 - 2002) Chapter-wise + Topic-wise Previous Years Solved P    AVAIL
# UGC NET Paper 1 Previous Year Papers | 2012- 2021 Previous Year Paper| Second Edition | By Pearson                               AVAIL
# Kiran SSC Mathematics Chapterwise and Typewise Solved Papers 1999 Till Date 11000+ Objective Questions(English Medium)(3458)     AVAIL
# Swamy's Handbook for CGS (English)                                                                                               AVAIL
# Quarterly Current Affairs 2022 Vol. 4 - October to December for Competitive Exams with Video eCourse 6th Edition | GK - Gener    AVAIL
# PMF IAS Physical Geography for UPSC 2023-24                                                                                      AVAIL
# SSC Maths 6800 TCS MCQ Chapter wise Hindi medium 3rd edition                                                                     AVAIL
# How to Prepare for VERBAL ABILITY & READING COMPREHENSION for CAT | 10th Edition | With CAT Practice Tests on Pull Marks | VA    AVAIL
# Complete Guide To NDA Maths By Arpit Choudhary                                                                                   AVAIL
# MTG Objective NCERT at your FINGERTIPS for NEET-AIIMS - Physics, Chemistry, Biology, Best NEET Books (Based on NCERT Pattern     AVAIL
# KVS: PGT (Common Subjects) Recruitment Exam Guide                                                                                AVAIL
# 35 Previous Year NTA NEET (UG) Physics, Chemistry & Biology Chapterwise & Topicwise Solved Papers with Value Added Notes (202    AVAIL
# MTG Objective NCERT at your Fingertips PHY/CHEM/BIO for NEET / JEE 2022 Exam (Combo of 3 Books)                                  AVAIL
# NCERT Notes Indian History Class 6-12 (Old+New) for UPSC , State PSC and Other Competitive Exams                                 AVAIL
# 28 Varsh UPSC Civil Services IAS Prarambhik Topic-wise Solved Papers 1 & 2 (1995 - 2022) 12th Edition                            AVAIL
# 14000+ Chapterwise Questions Objective General Studies for UPSC /Railway/Banking/NDA/CDS/SSC and other competitive Exams         AVAIL
# 23 JEE Main Online 2022 Previous Year Solved Papers (All sittings) with Rank Predictor                                           AVAIL
# Handbook of Mathematics                                                                                                          AVAIL
# Pathfinder CDS Combined Defence Services Entrance Examination                                                                    AVAIL
# An Introduction To Indian Art Part 1 : Textbook In Fine Arts For Class 11 - 11144                                                AVAIL
# MTG 35 Years NEET Previous Year Solved Question Papers with NEET Chapterwise Topicwise Solutions - Chemistry For NEET Exam 20    AVAIL
# English by Neetu SIngh Vol - 1 (Hindi Medium) | Kd Publication | New 2022                                                        AVAIL
# Oxford 2022 NTA UGC Paper 1 - NET/SET/JRF | Third Edition | Teaching and Research Aptitude with December 2021 Solved Papers      AVAIL
# Balasaheb Shinde - Sampoorna Engreji Vyakaran (English Vyakaran) - 3800+ Prashna - 12th. Ed./2022-23                             AVAIL
# Advanced Problems in Organic Chemistry for JEE - 16/edition, 2022-23 Session                                                     AVAIL
# TSPSC Group IV Paper I and II General Studies and Secretarial Ability Set of 4 Books [ TELUGU MEDIUM ]                           AVAIL
# NCC: Handbook of NCC Cadets for 'A', 'B' and 'C' Certificate Examinations                                                        AVAIL
# A Modern Approach to Logical Reasoning (2022-23) NEW EDITION                                                                     AVAIL
# Handbook of Chemistry                                                                                                            AVAIL
# Problems In GENERAL PHYSICS                                                                                                      AVAIL
# Quantitative Aptitude Quantum CAT                                                                                                AVAIL
# *******************************************************************************************************************************************
# Check Availiability
# 1. Search by Name
# 2. Search by Author
# 3. Search by Genres
# 4. Exit
# Enter your choice number: 4
# ********************************************************************************
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 2
# Scan / Type Book id: VLB0001
# Scan / Type student id: VU1F1819026
# Book issued sucessfully
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 2
# Scan / Type Book id: VLB0001
# Scan / Type student id: VU1F1819025
# VLB2456 is expired at  26-12-22 pay fine
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 3
# Scan / Type Book id: VLB0001
# Scan / Type student id: VU1F1819026
# Book return sucessfully
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 3
# Scan / Type Book id: VLB1427
# Scan / Type student id: VU1F1819049
# WARNING :Late submission on this VLB1427 pay fine
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 5
# Scan / Type student id: VU1F1819049
# You have to pay fine for 4 books
# Total Fine 2000
# Do you want to pay Type 'paid' for done payment paid
# VLB1427 04-01-23
# VLB0132 16-01-23
# Payment done and Penalty removed
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 4
# ********************************************************************************
# Welcome to Library Management
# 1. Book Avail
# 2. Book Issue / Reissue
# 3. Book return
# 4. List of Blacklist Student
# 5. Pay fine
# 6. Exit
# Enter your choice number: 6
