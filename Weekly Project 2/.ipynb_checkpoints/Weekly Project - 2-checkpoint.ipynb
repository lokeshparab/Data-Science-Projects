# %% [markdown]
# # A program to make an attendance system which can save your login and logout timings.

# %% [markdown]
# The following things are required to design attendance:
# 1. Dictionary data-types are needed to maintain attendance records. Pattern of dictionary is outlined below.
# ```python
#     attendance = {
#                    student_id:{
#                                student_name, division , gender
#                                dates: {
#                                        date_1: { login , logout },....
#
#                                        }
#                               },...
#                   }
# ```
# 2. JSON files will be used to store attendance records.
# 3. Files will keep on updating as per operation done

# %% [markdown]
# ## Filling Data

# %% [markdown]
# ### Import Libraries and Loading dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('test.csv')
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Creating Recors of students in Dictionary

# %%
attendance = {}

for no,name in enumerate(df.Name.unique()):
    
    stud_id  = ('vu00' if no<10 else 'vu0' if no<100 else 'vu') + str(no)
    division = str(df[df.Name == name].Pclass.values[0])
    gender   = str(df[df.Name == name].Sex.values[0])
    
    attendance[stud_id] = { 'name':name,
                            'division':division,
                            'gender':gender,
                            'date':{}
                          }
attendance
# Out:
# {'vu000': {'name': 'Kelly, Mr. James',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu001': {'name': 'Wilkes, Mrs. James (Ellen Needs)',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu002': {'name': 'Myles, Mr. Thomas Francis',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu003': {'name': 'Wirz, Mr. Albert',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu004': {'name': 'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu005': {'name': 'Svensson, Mr. Johan Cervin',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu006': {'name': 'Connolly, Miss. Kate',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu007': {'name': 'Caldwell, Mr. Albert Francis',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu008': {'name': 'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu009': {'name': 'Davies, Mr. John Samuel',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu010': {'name': 'Ilieff, Mr. Ylio',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu011': {'name': 'Jones, Mr. Charles Cresson',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu012': {'name': 'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu013': {'name': 'Howard, Mr. Benjamin',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu014': {'name': 'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu015': {'name': 'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#   'division': '2',
#   'gender': 'female',
#   'date': {}},
#  'vu016': {'name': 'Keane, Mr. Daniel',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu017': {'name': 'Assaf, Mr. Gerios',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu018': {'name': 'Ilmakangas, Miss. Ida Livija',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu019': {'name': 'Assaf Khalil, Mrs. Mariana (Miriam")"',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu020': {'name': 'Rothschild, Mr. Martin',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu021': {'name': 'Olsen, Master. Artur Karl',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu022': {'name': 'Flegenheim, Mrs. Alfred (Antoinette)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu023': {'name': 'Williams, Mr. Richard Norris II',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu024': {'name': 'Ryerson, Mrs. Arthur Larned (Emily Maria Borie)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu025': {'name': 'Robins, Mr. Alexander A',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu026': {'name': 'Ostby, Miss. Helene Ragnhild',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu027': {'name': 'Daher, Mr. Shedid',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu028': {'name': 'Brady, Mr. John Bertram',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu029': {'name': 'Samaan, Mr. Elias',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu030': {'name': 'Louch, Mr. Charles Alexander',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu031': {'name': 'Jefferys, Mr. Clifford Thomas',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu032': {'name': 'Dean, Mrs. Bertram (Eva Georgetta Light)',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu033': {'name': 'Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu034': {'name': 'Mock, Mr. Philipp Edmund',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu035': {'name': 'Katavelas, Mr. Vassilios (Catavelas Vassilios")"',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'v
',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu369': {'name': 'Pallas y Castello, Mr. Emilio',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu370': {'name': 'Giles, Mr. Edgar',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu371': {'name': 'Wilson, Miss. Helen Alice',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu372': {'name': 'Ismay, Mr. Joseph Bruce',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu373': {'name': 'Harbeck, Mr. William H',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu374': {'name': 'Dodge, Mrs. Washington (Ruth Vidaver)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu375': {'name': 'Bowen, Miss. Grace Scott',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu376': {'name': 'Kink, Miss. Maria',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu377': {'name': 'Cotterill, Mr. Henry Harry""',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu378': {'name': 'Hipkins, Mr. William Edward',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu379': {'name': 'Asplund, Master. Carl Edgar',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu380': {'name': "O'Connor, Mr. Patrick",
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu381': {'name': 'Foley, Mr. Joseph',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu382': {'name': 'Risien, Mrs. Samuel (Emma)',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu383': {'name': "McNamee, Mrs. Neal (Eileen O'Leary)",
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu384': {'name': 'Wheeler, Mr. Edwin Frederick""',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu385': {'name': 'Herman, Miss. Kate',
#   'division': '2',
#   'gender': 'female',
#   'date': {}},
#  'vu386': {'name': 'Aronsson, Mr. Ernst Axel Algot',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu387': {'name': 'Ashby, Mr. John',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu388': {'name': 'Canavan, Mr. Patrick',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu389': {'name': 'Palsson, Master. Paul Folke',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu390': {'name': 'Payne, Mr. Vivian Ponsonby',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu391': {'name': 'Lines, Mrs. Ernest H (Elizabeth Lindsey James)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu392': {'name': 'Abbott, Master. Eugene Joseph',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu393': {'name': 'Gilbert, Mr. William',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu394': {'name': 'Kink-Heilmann, Mr. Anton',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu395': {'name': 'Smith, Mrs. Lucien Philip (Mary Eloise Hughes)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu396': {'name': 'Colbert, Mr. Patrick',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu397': {'name': 'Frolicher-Stehli, Mrs. Maxmillian (Margaretha Emerentia Stehli)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu398': {'name': 'Larsson-Rondberg, Mr. Edvard A',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu399': {'name': 'Conlon, Mr. Thomas Henry',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu400': {'name': 'Bonnell, Miss. Caroline',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu401': {'name': 'Gale, Mr. Harry',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu402': {'name': 'Gibson, Miss. Dorothy Winifred',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu403': {'name': 'Carrau, Mr. Jose Pedro',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu404': {'name': 'Frauenthal, Mr. Isaac Gerald',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu405': {'name': 'Nourney, Mr. Alfred (Baron von Drachstedt")"',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu406': {'name': 'Ware, Mr. William Jeffery',
#   'division': '2',
#   'gender': 'male',
#   'date': {}},
#  'vu407': {'name': 'Widener, Mr. George Dunton',
#   'division': '1',
#   'gender': 'male',
#   'date': {}},
#  'vu408': {'name': 'Riordan, Miss. Johanna Hannah""',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu409': {'name': 'Peacock, Miss. Treasteall',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu410': {'name': 'Naughton, Miss. Hannah',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu411': {'name': 'Minahan, Mrs. William Edward (Lillian E Thorpe)',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu412': {'name': 'Henriksson, Miss. Jenny Lovisa',
#   'division': '3',
#   'gender': 'female',
#   'date': {}},
#  'vu413': {'name': 'Spector, Mr. Woolf',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu414': {'name': 'Oliva y Ocana, Dona. Fermina',
#   'division': '1',
#   'gender': 'female',
#   'date': {}},
#  'vu415': {'name': 'Saether, Mr. Simon Sivertsen',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu416': {'name': 'Ware, Mr. Frederick',
#   'division': '3',
#   'gender': 'male',
#   'date': {}},
#  'vu417': {'name': 'Peter, Master. Michael J',
#   'division': '3',
#   'gender': 'male',
#   'date': {}}}

# %% [markdown]
# ### Saving Data in json Format

# %%
import json

fd = open('Attendance.json','w')

json.dump(attendance,fd)

fd.close()

# %% [markdown]
# ## Operational Functions of Attendance system

# %% [markdown]
# ### Import Libraries

# %%
import json
from datetime import datetime as dt

# %% [markdown]
# ### Read and write attendance file functions

# %%
def read_file():
    
    fd = open('Attendance_.json','r')
    r  = json.loads(fd.read())
    fd.close()
    
    return r

def write_file(data):
    
    fd = open('Attendance_.json','w')
    fd.write(json.dumps(data))
    fd.close()

# %%
#write_file(attendance)

# %% [markdown]
# ### Save login and logout function

# %%
def login(stud_id):
    
    attendance = read_file()
    
    default_logout_time = '23:59:59'
    
    y  = dt.now()
    
    date = y.strftime('%d-%m-%Y')
    time = y.strftime('%H:%M:%S')
    
    print('-'*40)
    print('Login sucessfully on',date,'in',time)
    print('Now you can do your work')
    
    attendance[stud_id]['date'][date] = { 'login': time ,'logout': default_logout_time }
    
    write_file(attendance)

def logout(stud_id):
    
    attendance = read_file()
    
    y  = dt.now()
    
    date = y.strftime('%d-%m-%Y')
    time = y.strftime('%H:%M:%S')
    
    print('-'*40)
    
    if date in attendance[stud_id]['date'].keys():
        
        print('Logout Sucessfully!!')
        
        attendance[stud_id]['date'][date]['logout'] = time
        
        write_file(attendance)
    
    else:
        
        print('Session expire logout automatically!!')

# %% [markdown]
# ### Checking user has login already

# %%
def check_login(stud_id):
    
    attendance = read_file()
    
    y  = dt.now()
    date = y.strftime('%d-%m-%Y')
    
    return date in attendance[stud_id]['date'].keys

# %% [markdown]
# ### Checking and Printing Student Details

# %%
def student_details(stud_id):
    
    attendance = read_file()
    
    stud = attendance.get(stud_id,False)
    print('*'*40)
    
    if stud:
        print('Student details')
        print('-'*40)
        print('Student id          :',stud_id )
        print('Student Name        :',stud['name'] )
        print('Division            :',stud['division'] )
        print('Gender              :',stud['gender'] )
        print('No of days attended :',len( stud['date'] ) )
    
    else : 
        
        print('Invalid student id try again')
        return True

# %%
if __name__ == '__main__':
    
    while True:
        
        print('*'*40)
        stud_id = input('Enter the stud_id: ')
        
        if stud_id == 'exit':break
        
        if student_details(stud_id): continue
        
        print('-'*40)
        
        if check_login(stud_id):
            input('Press enter to login..')

            login(stud_id)
        else:
            input('Press enter to logout..')

            logout(stud_id)
# Out:
# ****************************************
# Enter the stud_idvu123
# ****************************************
# Student details
# ----------------------------------------
# Student id          : vu123
# Student Name        : Carver, Mr. Alfred John
# Division            : 3
# Gender              : male
# No of days attended : 1
# ----------------------------------------
# Press enter to login
# ----------------------------------------
# Login sucessfully on 07-10-2022 in 13:55:15
# Now you can do your work
# ----------------------------------------
# Press enter to logout
# ----------------------------------------
# Logout Sucessfully!!
# ****************************************
# Enter the stud_idexit

# %%
attendance = read_file()

attendance['vu123']
# Out:
# {'name': 'Carver, Mr. Alfred John',
#  'division': '3',
#  'gender': 'male',
#  'date': {'07-10-2022': {'login': '13:55:15', 'logout': '13:55:18'}}}
