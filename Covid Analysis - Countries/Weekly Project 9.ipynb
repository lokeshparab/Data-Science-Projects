# %% [markdown]
# # Statistical Analysis on COVID. Get the output for the following questions also:

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv('country_wise_latest.csv')
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.shape
# Out:
# (187, 15)

# %% [markdown]
# # What are the average cases in a country?

# %%
avg = df['Confirmed'].mean()
print(avg ,'are the average cases in a country')
# Out:
# 88130.935828877 are the average cases in a country

# %%
# calculating avg case of each country
avg_case = df.groupby('Country/Region').mean()['Confirmed']

# Making new dataframe
data = pd.DataFrame()
data['Country/Region'] = avg_case.index
data['Average cases'] = avg_case.values

# Printing final result
print('*'*54)
print('Average cases in a country'.center(54,' '))
print('*'*54)
print('|','Country/Region'.center(34),'|','Average cases','|')
print('-'*54)
for i in data.values:
    print('|',i[0].center(34),'|',str(i[1]).center(13),'|')
print('-'*54)
# Out:
# ******************************************************
#               Average cases in a country
# ******************************************************
# |           Country/Region           | Average cases |
# ------------------------------------------------------
# |            Afghanistan             |    36263.0    |
# |              Albania               |     4880.0    |
# |              Algeria               |    27973.0    |
# |              Andorra               |     907.0     |
# |               Angola               |     950.0     |
# |        Antigua and Barbuda         |      86.0     |
# |             Argentina              |    167416.0   |
# |              Armenia               |    37390.0    |
# |             Australia              |    15303.0    |
# |              Austria               |    20558.0    |
# |             Azerbaijan             |    30446.0    |
# |              Bahamas               |     382.0     |
# ...

# %% [markdown]
# # What is the total number of deaths as per the dataset?

# %%
tot = df['Deaths'].sum()
print(tot,'is the total number of deaths as per the dataset')
# Out:
# 654036 is the total number of deaths as per the dataset

# %% [markdown]
# # What is the total number of confirmed cases?

# %%
tot = df['Confirmed'].sum()
print(tot,'is the total number of confirmed cases')
# Out:
# 16480485 is the total number of confirmed cases
