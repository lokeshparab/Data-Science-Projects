# %%
import pandas as pd

# %%
df = pd.read_csv('Amazon_category.csv')
df.head()
# Out:
#    maincategory          subcategory                    category  \
# 0             0  tv, audio & cameras                 Televisions
# 1             0  tv, audio & cameras  Home Entertainment Systems
# 2             0  tv, audio & cameras                  Headphones
# 3             0  tv, audio & cameras                    Speakers
# 4             0  tv, audio & cameras        Home Audio & Theater
#
#                                                 link
# 0  https://www.amazon.in/gp/browse.html?node=1389...
# 1  https://www.amazon.in/gp/browse.html?node=1389...
# 2  https://www.amazon.in/gp/browse.html?node=1388...
# 3  https://www.amazon.in/gp/browse.html?node=1389...
# 4  https://www.amazon.in/gp/browse.html?node=1389...

# %%
for i in df['link']:
    print(i)
# Out:
# https://www.amazon.in/gp/browse.html?node=1389396031&ref_=nav_em_sbc_tvelec_television_0_2_9_2
# https://www.amazon.in/gp/browse.html?node=1389375031&ref_=nav_em_sbc_tvelec_home_ent_0_2_9_3
# https://www.amazon.in/gp/browse.html?node=1388921031&ref_=nav_em_sbc_tvelec_headphones_0_2_9_4
# https://www.amazon.in/gp/browse.html?node=1389365031&ref_=nav_em_sbc_tvelec_speakers_0_2_9_5
# https://www.amazon.in/gp/browse.html?node=1389387031&ref_=nav_em_sbc_tvelec_homeaud_all_0_2_9_6
# https://www.amazon.in/gp/browse.html?node=1388977031&ref_=nav_em_sbc_tvelec_cameras_0_2_9_7
# https://www.amazon.in/gp/browse.html?node=1389177031&ref_=nav_em_sbc_tvelec_dslr_0_2_9_8
# https://www.amazon.in/gp/browse.html?node=1389203031&ref_=nav_em_sbc_tvelec_security_0_2_9_9
# https://www.amazon.in/gp/browse.html?node=1388978031&ref_=nav_em_sbc_tvelec_cam_acc_0_2_9_10
# https://www.amazon.in/gp/browse.html?node=3677697031&ref_=nav_em_sbc_tvelec_musical_inst_0_2_9_11
# ...

# %%
link_pattern = 'https://www.amazon.in/s?rh=n%3A{node_value}&fs=true'
